# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('ex2data2.txt', header=None, names=['ScoreA', 'ScoreB', 'Accepted'])
pos_d = data[data['Accepted'] == 1]
neg_d = data[data['Accepted'] == 0]
ax, fig = plt.subplots()
fig.scatter(pos_d.ScoreA, pos_d.ScoreB)
fig.scatter(neg_d.ScoreA, neg_d.ScoreB, c='r', marker='x')
plt.show()

# %% [markdown]
# ### 生成多项式特征 $1, x_1, x_2, x_1^2, x_1x_2, x_2^2, ... ...$

# %%
x1 = data['ScoreA']
x2 = data['ScoreB']
data.drop(columns=['ScoreA', 'ScoreB'], inplace=True)
hp = 3
for i in range(hp+1):
    for j in range(i+1):
        data['F'+str(i-j)+str(j)] = np.power(x1, i-j)*np.power(x2, j)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\envs\d2l\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~\Anaconda3\envs\d2l\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\envs\d2l\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'scoreA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 x1 = data['scoreA']
#       2 x2 = data['scoreB']
#       3 data.drop(columns=['ScoreA', 'ScoreB'], inplace=True)
#
# File ~\Anaconda3\envs\d2l\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\Anaconda3\envs\d2l\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'scoreA'
