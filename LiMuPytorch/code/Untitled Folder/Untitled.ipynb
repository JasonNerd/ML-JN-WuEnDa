# %%
import torch
import sys
sys.path.append("../")
from MyUtils import d2laiUtils as d2l

# %%
train_iter, test_iter = d2l.loadFashionMnist(batch_size=18)
for X, y in train_iter:
    d2l.show_images(X.reshape(18, 28, 28), 3, 6, titles=d2l.get_fashion_mnist_labels(y));
    break
